# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 7.5 MB/s eta 0:00:008.2 MB/s eta 0:00:01
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 4.5 MB/s eta 0:00:005.5 MB/s eta 0:00:01
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /home/ahmad/miniconda3/lib/python3.11/site-packages (from optuna) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in /home/ahmad/miniconda3/lib/python3.11/site-packages (from optuna) (23.0)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 9.5 MB/s eta 0:00:000:00:010:00:01:01
# Requirement already satisfied: tqdm in /home/ahmad/miniconda3/lib/python3.11/site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /home/ahmad/miniconda3/lib/python3.11/site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /home/ahmad/miniconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna)
#   Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (602 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 9.8 MB/s eta 0:00:009.0 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ahmad/miniconda3/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.3 colorlog-6.8.2 greenlet-3.1.1 optuna-4.0.0 sqlalchemy-2.0.36

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import numpy as np
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
# Load FashionMNIST dataset
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# %%
# Create the dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Define the MLP model
class FashionNN(nn.Module):
    def __init__(self, hidden_dim):
        super(FashionNN, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(28 * 28, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.final_layer = nn.Linear(hidden_dim, 10)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.final_layer(x)
        
        return x

# %%
# Training function
def train(model, train_loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = correct / total
    return train_loss, train_acc

# %%
# Evaluation function
def evaluate(model, test_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    test_loss = running_loss / len(test_loader)
    test_acc = correct / total
    return test_loss, test_acc

# %%
# Main training loop
def run_training(hidden_dim, lr, num_epochs):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = FashionNN(hidden_dim).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    train_losses, train_accs, test_losses, test_accs = [], [], [], []

    for epoch in range(num_epochs):
        train_loss, train_acc = train(model, train_loader, criterion, optimizer, device)
        test_loss, test_acc = evaluate(model, test_loader, criterion, device)

        train_losses.append(train_loss)
        train_accs.append(train_acc)
        test_losses.append(test_loss)
        test_accs.append(test_acc)

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")
        print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")

    return model, train_losses, train_accs, test_losses, test_accs

# %%
# Run the training
hidden_dim = 128
lr = 0.001
num_epochs = 10
model, train_losses, train_accs, test_losses, test_accs = run_training(hidden_dim, lr, num_epochs)
# Out:
# Epoch 1/10
# Train Loss: 0.5104, Train Acc: 0.8178
# Test Loss: 0.4739, Test Acc: 0.8291
# Epoch 2/10
# Train Loss: 0.3710, Train Acc: 0.8633
# Test Loss: 0.3828, Test Acc: 0.8647
# Epoch 3/10
# Train Loss: 0.3340, Train Acc: 0.8765
# Test Loss: 0.3594, Test Acc: 0.8691
# Epoch 4/10
# Train Loss: 0.3089, Train Acc: 0.8858
# Test Loss: 0.3688, Test Acc: 0.8614
# Epoch 5/10
# Train Loss: 0.2935, Train Acc: 0.8905
# Test Loss: 0.3368, Test Acc: 0.8766
# Epoch 6/10
# Train Loss: 0.2776, Train Acc: 0.8956
# Test Loss: 0.3308, Test Acc: 0.8842
# Epoch 7/10
# Train Loss: 0.2646, Train Acc: 0.9011
# Test Loss: 0.3397, Test Acc: 0.8753
# Epoch 8/10
# Train Loss: 0.2548, Train Acc: 0.9029
# Test Loss: 0.3245, Test Acc: 0.8841
# Epoch 9/10
# Train Loss: 0.2432, Train Acc: 0.9075
# Test Loss: 0.3400, Test Acc: 0.8816
# Epoch 10/10
# Train Loss: 0.2318, Train Acc: 0.9121
# Test Loss: 0.3236, Test Acc: 0.8860

# %%
# Plot learning curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Learning Curves - Loss')

plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train Accuracy')
plt.plot(test_accs, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Learning Curves - Accuracy')
plt.tight_layout()
plt.show()

# %%
# Function to get predictions and true labels
def get_predictions(model, loader, device):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = outputs.max(1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return np.array(all_preds), np.array(all_labels)

# %%
# Get predictions
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
y_pred, y_true = get_predictions(model, test_loader, device)

# %%
# Plot confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Visualize some images with predictions
def plot_images_with_predictions(model, loader, device, num_images=5):
    model.eval()
    images, labels = next(iter(loader))
    images, labels = images.to(device), labels.to(device)
    outputs = model(images)
    _, preds = outputs.max(1)

    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i in range(num_images):
        img = images[i].cpu().squeeze().numpy()
        ax = axes[i]
        ax.imshow(img, cmap='gray')
        ax.set_title(f"True: {labels[i].item()}\nPred: {preds[i].item()}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# %%
plot_images_with_predictions(model, test_loader, device)

# %%
# Optuna optimization
def objective(trial):
    hidden_dim = trial.suggest_int('hidden_dim', 32, 256)
    lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
    
    model, _, _, _, _ = run_training(hidden_dim, lr, num_epochs=5)
    _, test_acc = evaluate(model, test_loader, nn.CrossEntropyLoss(), device)
    
    return test_acc

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)

print("Best trial:")
trial = study.best_trial
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-10-21 17:17:43,215] A new study created in memory with name: no-name-647c05ab-53ac-4c55-b843-6a9d5bd6a7ab
# /tmp/ipykernel_8383/2296698973.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# Epoch 1/5
# Train Loss: 0.6419, Train Acc: 0.7727
# Test Loss: 0.5548, Test Acc: 0.8161
# Epoch 2/5
# Train Loss: 0.5549, Train Acc: 0.8109
# Test Loss: 0.5590, Test Acc: 0.8094
# Epoch 3/5
# Train Loss: 0.5388, Train Acc: 0.8193
# Test Loss: 0.5720, Test Acc: 0.8094
# Epoch 4/5
# Train Loss: 0.5325, Train Acc: 0.8195
# Test Loss: 0.6242, Test Acc: 0.8165
# Epoch 5/5
# Train Loss: 0.5309, Train Acc: 0.8224
# Test Loss: 0.6169, Test Acc: 0.7713
# [I 2024-10-21 17:18:39,936] Trial 0 finished with value: 0.7713 and parameters: {'hidden_dim': 166, 'lr': 0.0206425532346848}. Best is trial 0 with value: 0.7713.
# Epoch 1/5
# Train Loss: 0.5054, Train Acc: 0.8166
# Test Loss: 0.4492, Test Acc: 0.8339
# Epoch 2/5
# Train Loss: 0.3692, Train Acc: 0.8636
# Test Loss: 0.3792, Test Acc: 0.8646
# Epoch 3/5
# Train Loss: 0.3337, Train Acc: 0.8765
# Test Loss: 0.4021, Test Acc: 0.8527
# Epoch 4/5
# Train Loss: 0.3110, Train Acc: 0.8851
# Test Loss: 0.3542, Test Acc: 0.8748
# Epoch 5/5
# Train Loss: 0.2926, Train Acc: 0.8911
# Test Loss: 0.3554, Test Acc: 0.8701
# [I 2024-10-21 17:19:34,296] Trial 1 finished with value: 0.8701 and parameters: {'hidden_dim': 123, 'lr': 0.0010262639531083274}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 0.6598, Train Acc: 0.7717
# Test Loss: 0.5084, Test Acc: 0.8226
# Epoch 2/5
# Train Loss: 0.4470, Train Acc: 0.8424
# Test Loss: 0.4521, Test Acc: 0.8375
# Epoch 3/5
# Train Loss: 0.4105, Train Acc: 0.8545
# Test Loss: 0.4426, Test Acc: 0.8396
# Epoch 4/5
# Train Loss: 0.3894, Train Acc: 0.8608
# Test Loss: 0.4320, Test Acc: 0.8446
# Epoch 5/5
# Train Loss: 0.3727, Train Acc: 0.8659
# Test Loss: 0.4123, Test Acc: 0.8534
# [I 2024-10-21 17:20:21,276] Trial 2 finished with value: 0.8534 and parameters: {'hidden_dim': 38, 'lr': 0.00043575805383991734}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 0.6823, Train Acc: 0.7681
# Test Loss: 0.5110, Test Acc: 0.8214
# Epoch 2/5
# Train Loss: 0.4459, Train Acc: 0.8442
# Test Loss: 0.4682, Test Acc: 0.8321
# Epoch 3/5
# Train Loss: 0.4027, Train Acc: 0.8581
# Test Loss: 0.4391, Test Acc: 0.8415
# Epoch 4/5
# Train Loss: 0.3784, Train Acc: 0.8657
# Test Loss: 0.3973, Test Acc: 0.8567
# Epoch 5/5
# Train Loss: 0.3590, Train Acc: 0.8722
# Test Loss: 0.3916, Test Acc: 0.8613
# [I 2024-10-21 17:21:24,757] Trial 3 finished with value: 0.8613 and parameters: {'hidden_dim': 249, 'lr': 9.591080715558622e-05}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 0.6088, Train Acc: 0.7825
# Test Loss: 0.5316, Test Acc: 0.8093
# Epoch 2/5
# Train Loss: 0.5058, Train Acc: 0.8274
# Test Loss: 0.5980, Test Acc: 0.8064
# Epoch 3/5
# Train Loss: 0.5001, Train Acc: 0.8306
# Test Loss: 0.5280, Test Acc: 0.8124
# Epoch 4/5
# Train Loss: 0.4850, Train Acc: 0.8332
# Test Loss: 0.5389, Test Acc: 0.8297
# Epoch 5/5
# Train Loss: 0.4807, Train Acc: 0.8388
# Test Loss: 0.5111, Test Acc: 0.8196
# [I 2024-10-21 17:22:18,309] Trial 4 finished with value: 0.8196 and parameters: {'hidden_dim': 64, 'lr': 0.01893493107800222}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 1.1388, Train Acc: 0.6502
# Test Loss: 0.7359, Test Acc: 0.7397
# Epoch 2/5
# Train Loss: 0.6398, Train Acc: 0.7799
# Test Loss: 0.6069, Test Acc: 0.7886
# Epoch 3/5
# Train Loss: 0.5521, Train Acc: 0.8113
# Test Loss: 0.5489, Test Acc: 0.8086
# Epoch 4/5
# Train Loss: 0.5088, Train Acc: 0.8269
# Test Loss: 0.5189, Test Acc: 0.8201
# Epoch 5/5
# Train Loss: 0.4813, Train Acc: 0.8350
# Test Loss: 0.4976, Test Acc: 0.8272
# [I 2024-10-21 17:23:21,969] Trial 5 finished with value: 0.8272 and parameters: {'hidden_dim': 209, 'lr': 2.1126972279530254e-05}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 0.6366, Train Acc: 0.7807
# Test Loss: 0.4857, Test Acc: 0.8285
# Epoch 2/5
# Train Loss: 0.4288, Train Acc: 0.8484
# Test Loss: 0.4456, Test Acc: 0.8401
# Epoch 3/5
# Train Loss: 0.3925, Train Acc: 0.8603
# Test Loss: 0.4215, Test Acc: 0.8501
# Epoch 4/5
# Train Loss: 0.3683, Train Acc: 0.8680
# Test Loss: 0.3940, Test Acc: 0.8595
# Epoch 5/5
# Train Loss: 0.3491, Train Acc: 0.8755
# Test Loss: 0.3859, Test Acc: 0.8616
# [I 2024-10-21 17:24:18,357] Trial 6 finished with value: 0.8616 and parameters: {'hidden_dim': 110, 'lr': 0.00023259443857613678}. Best is trial 1 with value: 0.8701.
# Epoch 1/5
# Train Loss: 0.5233, Train Acc: 0.8132
# Test Loss: 0.4115, Test Acc: 0.8509
